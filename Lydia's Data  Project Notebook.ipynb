# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Lydia Oghosa Edogiawerie**

# %% [markdown]
# UX Designer and Software developer

# %% [markdown]
#  *I am interested in data science because I want to integrate design, data science and software development to help suite users painpoints*

# %% [markdown]
# ### I will run a short code that shows basic mathematics

# %%
3065+11006
# Out:
# 14071

# %%
12554/6453
# Out:
# 1.9454517278785062

# %%
1234-666
# Out:
# 568

# %%
53434*466
# Out:
# 24900244

# %% [markdown]
# | NYSC    | What next  |
# | --------| ---------- |
# | Allawee | Nothing    |

# %% [markdown]
# [lydia's_portfolio](https://lydiaedogiawerie.myportfolio.com/)

# %% [markdown]
# > Lydia

# %% [markdown]
# - Lydia
# - Go
# - Come
# - Near

# %% [markdown]
# ***

# %% [markdown]
# <font color=green|>Lydia</font>
